# %%
import pandas as pd
import numpy as np

df= pd.read_csv('da_lerning/204/empl.csv', delimiter=',')
    # читаем файл с расширением csv, указываем разделитель в виде запятой

table_df = pd.DataFrame(df)

# %%
import pandas as pd
import numpy as np

data = { 'color': ['red', 'blue', 'yellow', 'black', 'green', 'white'],
        'object': ['ball', 'car', 'ice', 'tea', 'apple', 'clock'],
        'price': ['2.45', '310.1', '0.3', '4.31', '5.45', '13.81']}
        # здесь мы создаем датасет самостоятельно, как видно из записи выше, по сути
        # это большой словарик с данными, разделенными на колонки и строки
        # В ДАННОМ СЛУЧАЕ, мы создали именно DataFrame !!! не стоит путать с series.

frame = pd.DataFrame(data)
frame
        # после чего вызываем этот датасет и получаем ответ в виде таблицы
# Out:
#     color object  price
# 0     red   ball   2.45
# 1    blue    car  310.1
# 2  yellow    ice    0.3
# 3   black    tea   4.31
# 4   green  apple   5.45
# 5   white  clock  13.81

# %% [markdown]
# ![first_df.png](attachment:first_df.png)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\training_dataset\\pandas_tutorial_read.csv', delimiter = ';', 
                 names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])
    # при вызове df без каких либо дополнительных параметров
    # будет вызвана вся таблица значений
df.head(5)
    # функция head вызывает определенное количество строк
    # или случайные строки с помощью функции sample
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\training_dataset\\pandas_tutorial_read.csv', delimiter = ';', 
                 names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

df[['country', 'user_id']].head(5)
    # для выбора определеннх колонок можно воспользоваться
    # методом выше, так же можно указать количество колонок
    # точно так же как мы делали ранее
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\training_dataset\\pandas_tutorial_read.csv', delimiter = ';', 
                 names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

    # Иногда (особенно в проектах аналитического прогнозирования) нужно получить объекты Series вместе DataFrames. Это можно сделать с помощью одного из способов:
    # article_read.user_id
    # article_read[‘user_id’]

df.user_id.head(7)
    # таким образом мы сделали из объекта DataFrames 
    # объект Series, а так же, через точку мы можем
    # вызывать методы подряд
# Out:
# 0    2458151261
# 1    2458151262
# 2    2458151263
# 3    2458151264
# 4    2458151265
# 5    2458151266
# 6    2458151267
# Name: user_id, dtype: int64

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\training_dataset\\pandas_tutorial_read.csv', delimiter = ';', 
                 names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

df[df.source == 'SEO'].head(7)
    # df[df.source == 'SEO'] с помощью этого метода мы фильтруем значения
    # по колонке SEO и выбираем только положительные значения, то есть True
# Out:
#             my_datetime event    country     user_id source          topic
# 0   2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1   2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11  2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15  2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16  2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# 18  2018-01-01 00:13:39  read  country_4  2458151279    SEO  North America
# 26  2018-01-01 00:20:18  read  country_5  2458151287    SEO  North America
