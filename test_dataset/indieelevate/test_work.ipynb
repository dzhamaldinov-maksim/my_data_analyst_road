# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# print(matplotlib.get_backend())

plt.plot([1, 2, -6, 8, 4])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data.csv')

df.info()
df.to_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data_2.csv')

# sec = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data_2.csv')
# sec.head(5)

copy_df = df.copy()
print(copy_df)
copy_df['Age'].max()

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of mtcars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   applicant_name   325 non-null    object
#  1   Age              281 non-null    float64
#  2   Ответ на вопрос  325 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 7.7+ KB
#     applicant_name   Age   Ответ на вопрос
# 0           name_0  49.0               нет
# 1           name_1  37.0                да
# 2           name_2  18.0               нет
# 3           name_3  36.0  неверное решение
# 4           name_4  31.0                да
# ..             ...   ...               ...
# 320       name_320  19.0               нет
# 321       name_321  21.0               нет
# 322       name_322  33.0               нет
# 323       name_323  22.0                да
# 324       name_324   NaN                да
#
# [325 rows x 3 columns]
# np.float64(186.0)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
 #0
df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data_2.csv')

#1
# df.info()

#2
df.rename(columns={'Ответ на вопрос': 'answer', 'Unnamed: 0': 'index'}, inplace=True)

df.duplicated() 
df.drop_duplicates(inplace=True)

df.dropna(inplace=True) 
df.describe()
# data = df.loc[df['Age'] < 100]

# #3
# plt.figure(figsize=(25,15), dpi=400) 
# sns.pairplot(data, hue="answer")
# plt.show()
# Out:
#             index         Age
# count  281.000000  281.000000
# mean   160.519573   26.800712
# std     95.467873   11.999232
# min      0.000000   15.000000
# 25%     76.000000   21.000000
# 50%    159.000000   24.000000
# 75%    244.000000   31.000000
# max    323.000000  186.000000

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data_2.csv')

# df.info() #1

df.rename(columns={'Ответ на вопрос': 'answer', 'Unnamed: 0': 'index'}, inplace=True)
# FIRST VAR
copy_frame = df.copy()
# copy_frame = copy_frame.drop(columns=['index', 'applicant_name'])

copy_frame.duplicated() #2
copy_frame.drop_duplicates()


copy_frame.dropna() #3

# Plot
plt.figure(figsize=(25,15), dpi= 400)
sns.pairplot(copy_frame.loc[(copy_frame['Age'] < 80) & (copy_frame['Age'] > 17)], hue="answer")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data_2.csv')

# INFO
# df.info() 

df.rename(columns={'Ответ на вопрос': 'answer', 'Unnamed: 0': 'index'}, inplace=True)
copy_frame = df.copy()
# copy_frame = copy_frame.drop(columns=['index', 'applicant_name'])

# DUPLICATE
copy_frame.duplicated() 
copy_frame.drop_duplicates(inplace=True)

# NAN
copy_frame.dropna(inplace=True) 

# FILTRED
filtred_data = copy_frame.loc[(copy_frame['Age'] < 80) & (copy_frame['Age'] > 17) & (copy_frame['answer'] == 'нет')]
filtred_data.describe() 

# PLOT
plt.figure(figsize=(25,15), dpi= 400)
sns.pairplot(filtred_data.loc[(copy_frame['Age'] < 80) & (copy_frame['Age'] > 17)], hue="answer")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\Максим Феликсович\\Documents\\GitHub\\my_data_analyst_road\\test_dataset\\indieelevate\\data.csv')

# df.info() # смотрим информацию о dataset
# df.columns # смотрим какие колонки есть в dataset

# drop_row = df.dropna()
# df.isnull().sum().sum()
# ищем пропущенные значения

missing_rows = df[df.isnull().any(axis=1)].index.tolist()
# выбираем наш dataframe применяем к нему функцию isnull(), которая показывает наличие строк с типом данных NaN & null, затем к isnull() мы применили функцию any() для формирования объекта Series с булиевыми значениями, из которого в последствии формируем список всех строк со значеними NaN & null
# print(missing_rows)

# df.iloc[missing_rows]
# выводим все значения

data_cleared_of_omission = df.dropna()
# избавляемся от значений NaN & null

rename_answer = data_cleared_of_omission.rename(columns={'Ответ на вопрос': 'answer', 'Age': 'age'})
# заменяем название колонок на более удобные

# rename_answer['Age'].describe()
# смотрим на распределение возрастов, выясняем максимальный и минимальный возраст

right_age = rename_answer.loc[(rename_answer['age'] < 66) & (rename_answer['age'] >= 18)]
# right_age.describe()
# выполняем сортировку данных по возрасту, не считая тех людей что младше возраста совершеннолетия и тех, чей возраст выходит за рамки нормы, например такое значение как 186

what_answer_we_have = right_age['answer'].unique()
# смотрим какие ответы у нас есть
# what_answer_we_have

clean_answer = right_age.replace('неверное решение', 'нет')
clean_answer = clean_answer.replace("да, но очень плохо описано", 'да')
# # заменяем значения в ответах 

group_by_answer = clean_answer.groupby('answer')
group_by_answer.size()
# Out:
# answer
# да     126
# нет    147
# dtype: int64
